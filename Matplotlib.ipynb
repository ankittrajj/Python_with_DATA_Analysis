# %%
#Matplotlib -----> Mathematical Plotting Library

#LinePlot
#Histogram
#Barchart
#Pie Chart
#Subplot

# LinePlot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline    
# magical line above

# %%
#Graph
no_of_classes = np.array([1,2,3,4,5,6,7])
no_of_students = np.array([4,9,6,4,10,8,6])
plt.plot(no_of_classes,no_of_students)
# plt.show()

# %%
no_of_classes = np.array([1,2,3,4,5,6,7])
no_of_students = np.array([4,9,6,4,10,8,6])
plt.plot(no_of_classes,no_of_students,c='g',LineStyle = '-.')
# Out:
# <ipython-input-3-66e96e005f54>:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(no_of_classes,no_of_students,c='g',LineStyle = '-.')

# %%
no_of_classes = np.array([1,2,3,4,5,6,7])
no_of_students = np.array([4,9,6,4,10,8,6])
plt.plot(no_of_classes,no_of_students,linewidth=2)
plt.xlabel('No_of_Classes')
plt.ylabel('No_of_Students')
plt.title('Attandance')
# Out:
# Text(0.5, 1.0, 'Attandance')

# %%
#BarChart
subject = ['AI','ML','DBMS','SQL']
m1=[5,50,12,14]
m2=[12,14,20,5]
m3=[10,18,30,20]
plt.bar(subject,m1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m2)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(subject,m3)
# Out:
# <BarContainer object of 4 artists>

# %%
# ml=50
# dbms = 20
# dbms = 30
# overall sabse jyda classes kon si thi ----> total 3month 
# me max class kon si hai 
# ml==dbms
plt.bar(subject,m1,width=.5,align='center')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,align='edge')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject,m1,m2,m3,color = ['green','red','yellow'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(subject, m1 , color='g')
plt.bar(subject, m2, color='r')
plt.bar (subject, m3,color='y')
# Out:
# <BarContainer object of 4 artists>

# %%
#PieChart
a = np.array([32,35,78,90])
myLabel=['India','America','USA','Canada']
mycolor = ['red','green','yellow','black']
# b=np.array([21])
plt.pie(a,labels = myLabel,colors=mycolor)
# plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x18d36542c10>,
#   <matplotlib.patches.Wedge at 0x18d3655b130>,
#   <matplotlib.patches.Wedge at 0x18d3655b5e0>,
#   <matplotlib.patches.Wedge at 0x18d3655ba60>],
#  [Text(1.0008726896721896, 0.4563483965879109, 'India'),
#   Text(0.26928372604579065, 1.0665300159333988, 'America'),
#   Text(-1.0484108718460243, 0.33291837407247316, 'USA'),
#   Text(0.3953486012424026, -1.0264986524568243, 'Canada')])

# %%
#Histogram
x = np.array([110,30,56,76,8,99,5,120,1])
# y = np.array([2,4,5,9,6,7])
plt.hist(x)
# Out:
# (array([3., 0., 1., 0., 1., 0., 1., 0., 1., 2.]),
#  array([  1. ,  12.9,  24.8,  36.7,  48.6,  60.5,  72.4,  84.3,  96.2,
#         108.1, 120. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
x =np.array([20,23,45,89,76,67])
plt.hist(x,bins=5,rwidth=0.5)
# Out:
# (array([2., 1., 0., 1., 2.]),
#  array([20. , 33.8, 47.6, 61.4, 75.2, 89. ]),
#  <BarContainer object of 5 artists>)

# %%
#subplot
s = np.array([231,672,893,560])
d = np.array([67,98,12,77])
plt.plot(s,d)

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2,1,1)
plt.plot(x,y)

a =np.array([3,4,8,6])
b = np.array([2,9,7,5])
plt.subplot(2,1,2)
plt.plot(a,b)
