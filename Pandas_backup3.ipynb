# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r'C:\Users\ddugky\Downloads\archive (2)\matches.csv')

# %%
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
import seaborn as sns

# %%
#isnull
#corr
df.corr()
# Out:
#                       id  dl_applied  win_by_runs  win_by_wickets
# id              1.000000   -0.011658    -0.039403       -0.012239
# dl_applied     -0.011658    1.000000    -0.016349       -0.011631
# win_by_runs    -0.039403   -0.016349     1.000000       -0.560420
# win_by_wickets -0.012239   -0.011631    -0.560420        1.000000

# %%
df.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
#heatmap
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#replace
# interpolate
# loc  & iloc
# groupby
# merging
# concat
# join
# append

# %%
#replace
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
rep = df.replace(['Hyderabad'],['Noida'])

# %%
rep
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017          Noida  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019          Noida  12-05-2019               Mumbai Indians
#
# ...

# %%
rep1 =df.replace(method='backfill')

# %%
rep1
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
sns.heatmap(rep1.isnull())
# Out:
# <AxesSubplot:>

# %%
t = df.replace('Hyderabad',value=5)

# %%
t
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017              5  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019              5  12-05-2019               Mumbai Indians
#
# ...

# %%
limit = df.replace('Hyderabad',20,limit=2)

# %%
limit.tail()
# Out:
#         id    Season           city        date                  team1  \
# 751  11347  IPL-2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415  IPL-2019             20  12-05-2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
a = df['city']='Hyderabad'

# %%
df.
# Out:
#   File "C:\Users\ddugky\AppData\Local\Temp/ipykernel_2632/791285630.py", line 1
#     df.
#        ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#         id    Season       city        date                        team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017  Hyderabad  06-04-2017               Mumbai Indians
# 2        3  IPL-2017  Hyderabad  07-04-2017                Gujarat Lions
# 3        4  IPL-2017  Hyderabad  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017  Hyderabad  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...        ...         ...                          ...
# 751  11347  IPL-2019  Hyderabad  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019  Hyderabad  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Hyderabad  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Hyderabad  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df= pd.read_csv(r'C:\Users\ddugky\Downloads\archive (2)\matches.csv')

# %%
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
df['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
s = df.replace(method = 'bfill',limit=10)

# %%
s
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
s.tail(50)
# Out:
#         id    Season           city        date                        team1  \
# 706  11147  IPL-2019      Hyderabad  31-03-2019          Sunrisers Hyderabad
# 707  11148  IPL-2019        Chennai  31-03-2019          Chennai Super Kings
# 708  11149  IPL-2019         Mohali  01-04-2019              Kings XI Punjab
# 709  11150  IPL-2019         Jaipur  02-04-2019  Royal Challengers Bangalore
# 710  11151  IPL-2019         Mumbai  03-04-2019               Mumbai Indians
# 711  11152  IPL-2019          Delhi  04-04-2019               Delhi Capitals
# 712  11153  IPL-2019      Bengaluru  05-04-2019  Royal Challengers Bangalore
# 713  11309  IPL-2019        Chennai  06-04-2019          Chennai Super Kings
# 714  11310  IPL-2019      Hyderabad  06-04-2019               Mumbai Indians
# 715  11311  IPL-2019      Bengaluru  07-04-2019  Royal Challengers Bangalore
# 716  11312  IPL-2019         Jaipur  07-04-2019             Rajasthan Royals
# ...

# %%
s.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
s.replace('field',method='bfill',limit=2)
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
# loc & iloc
# loc
df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df['team1'].loc[0:5:2]
# Out:
# 0            Sunrisers Hyderabad
# 2                  Gujarat Lions
# 4    Royal Challengers Bangalore
# Name: team1, dtype: object

# %%
#iloc
df['team2'].iloc[0:10:3]
# Out:
# 0    Royal Challengers Bangalore
# 3                Kings XI Punjab
# 6                 Mumbai Indians
# 9                 Mumbai Indians
# Name: team2, dtype: object

# %%
df.iloc[:,0:2]
# Out:
#         id    Season
# 0        1  IPL-2017
# 1        2  IPL-2017
# 2        3  IPL-2017
# 3        4  IPL-2017
# 4        5  IPL-2017
# ..     ...       ...
# 751  11347  IPL-2019
# 752  11412  IPL-2019
# 753  11413  IPL-2019
# 754  11414  IPL-2019
# 755  11415  IPL-2019
#
# [756 rows x 2 columns]

# %%
df.Season
# Out:
# 0      IPL-2017
# 1      IPL-2017
# 2      IPL-2017
# 3      IPL-2017
# 4      IPL-2017
#          ...
# 751    IPL-2019
# 752    IPL-2019
# 753    IPL-2019
# 754    IPL-2019
# 755    IPL-2019
# Name: Season, Length: 756, dtype: object

# %%
df['Season']
# Out:
# 0      IPL-2017
# 1      IPL-2017
# 2      IPL-2017
# 3      IPL-2017
# 4      IPL-2017
#          ...
# 751    IPL-2019
# 752    IPL-2019
# 753    IPL-2019
# 754    IPL-2019
# 755    IPL-2019
# Name: Season, Length: 756, dtype: object

# %%
# groupby
df.groupby(by='team1').mean()
# Out:
#                                        id  dl_applied  win_by_runs  \
# team1
# Chennai Super Kings           1568.292135    0.033708    20.056180
# Deccan Chargers                219.186047    0.000000     9.790698
# Delhi Capitals               11250.666667    0.000000    15.333333
# Delhi Daredevils              1268.402778    0.055556     9.722222
# Gujarat Lions                  279.571429    0.000000     0.071429
# Kings XI Punjab               1750.879121    0.021978    10.219780
# Kochi Tuskers Kerala           264.000000    0.000000     3.285714
# Kolkata Knight Riders         2038.939759    0.036145    12.867470
# Mumbai Indians                2091.257426    0.000000    18.475248
# Pune Warriors                  345.000000    0.000000     6.950000
# Rajasthan Royals              2041.328358    0.014925    13.358209
# Rising Pune Supergiant          27.875000    0.000000    15.375000
# Rising Pune Supergiants        600.285714    0.142857     0.000000
# ...

# %%
x = df.groupby(by='team1').mean()

# %%
x
# Out:
#                                        id  dl_applied  win_by_runs  \
# team1
# Chennai Super Kings           1568.292135    0.033708    20.056180
# Deccan Chargers                219.186047    0.000000     9.790698
# Delhi Capitals               11250.666667    0.000000    15.333333
# Delhi Daredevils              1268.402778    0.055556     9.722222
# Gujarat Lions                  279.571429    0.000000     0.071429
# Kings XI Punjab               1750.879121    0.021978    10.219780
# Kochi Tuskers Kerala           264.000000    0.000000     3.285714
# Kolkata Knight Riders         2038.939759    0.036145    12.867470
# Mumbai Indians                2091.257426    0.000000    18.475248
# Pune Warriors                  345.000000    0.000000     6.950000
# Rajasthan Royals              2041.328358    0.014925    13.358209
# Rising Pune Supergiant          27.875000    0.000000    15.375000
# Rising Pune Supergiants        600.285714    0.142857     0.000000
# ...

# %%
y = df.groupby(level=-1).mean()

# %%
y.head()
# Out:
#     id  dl_applied  win_by_runs  win_by_wickets
# 0  1.0         0.0         35.0             0.0
# 1  2.0         0.0          0.0             7.0
# 2  3.0         0.0          0.0            10.0
# 3  4.0         0.0          0.0             6.0
# 4  5.0         0.0         15.0             0.0

# %%
y1 = df.groupby(level=0).mean()

# %%
y1.head()
# Out:
#     id  dl_applied  win_by_runs  win_by_wickets
# 0  1.0         0.0         35.0             0.0
# 1  2.0         0.0          0.0             7.0
# 2  3.0         0.0          0.0            10.0
# 3  4.0         0.0          0.0             6.0
# 4  5.0         0.0         15.0             0.0

# %%
t = df.groupby(by = 'team1',level=0,sort=False).sum()

# %%
t.head(10)
# Out:
#    id  dl_applied  win_by_runs  win_by_wickets
# 0   1           0           35               0
# 1   2           0            0               7
# 2   3           0            0              10
# 3   4           0            0               6
# 4   5           0           15               0
# 5   6           0            0               9
# 6   7           0            0               4
# 7   8           0            0               8
# 8   9           0           97               0
# 9  10           0            0               4

# %%
f = df.groupby(by='city',sort=True).sum()

# %%
f
# Out:
#                     id  dl_applied  win_by_runs  win_by_wickets
# city
# Abu Dhabi         3263           0          157              16
# Ahmedabad         4863           0          180              38
# Bangalore        22299           3         1263             232
# Bengaluru       134379           0           71              34
# Bloemfontein       326           0           14               6
# Cape Town          858           1          145              18
# Centurion         1842           1           81              49
# Chandigarh       15325           0          576             167
# Chennai         113322           0          871             142
# Cuttack           2534           0           73              20
# Delhi           153898           3         1040             227
# Dharamsala        2949           0          279              23
# Durban            2147           1          159              33
# East London        432           0           87               7
# ...

# %%
#merging
dict1 = {
    'name':['abc'],
    'class':[2],
    'age':[321],
    'hobby':['dance']
}

# %%
dict1
# Out:
# {'name': ['abc'], 'class': [2], 'age': [321], 'hobby': ['dance']}

# %%
dict2={
    'age':[32],
    'hobby':['music']
}

# %%
print(dict2)
# Out:
# {'age': [32], 'hobby': ['music']}

# %%
f = pd.DataFrame(dict1)

# %%
f
# Out:
#   name  class  age  hobby
# 0  abc      2  321  dance

# %%
f1=pd.DataFrame(dict2)

# %%
f1
# Out:
#    age  hobby
# 0   32  music

# %%
s = pd.merge(f,f1,how='left')

# %%
print(s)
# Out:
#   name  class  age  hobby
# 0  abc      2  321  dance

# %%
s = pd.merge(f,f1,how='right')

# %%
s
# Out:
#   name  class  age  hobby
# 0  NaN    NaN   32  music

# %%
s = pd.merge(f,f1,how='inner')

# %%
s
# Out:
# Empty DataFrame
# Columns: [name, class, age, hobby]
# Index: []

# %%
s = pd.merge(f,f1,how='outer')

# %%
s
# Out:
#   name  class  age  hobby
# 0  abc    2.0  321  dance
# 1  NaN    NaN   32  music

# %%
#concate
#append
a=['1','2','3']
b=['2','3','4']
c = a+b
print(c)
# Out:
# ['1', '2', '3', '2', '3', '4']

# %%
a=[1,2,3,99.76]

# %%
print(a)
# Out:
# [1, 2, 3, 99.76]

# %%
a.append('Ram')

# %%
a
# Out:
# [1, 2, 3, 99.76, 'Ram']

# %%
w = df['city'].append(pd.Series(['Delhi'],index = [756]))

# %%
w
# Out:
# 0          Hyderabad
# 1               Pune
# 2             Rajkot
# 3             Indore
# 4          Bangalore
#            ...
# 752          Chennai
# 753    Visakhapatnam
# 754    Visakhapatnam
# 755        Hyderabad
# 756            Delhi
# Length: 757, dtype: object

# %%
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...
